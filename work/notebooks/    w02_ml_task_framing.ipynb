# %% [markdown]
# <a href="https://colab.research.google.com/github/zkhadija132/flyrank-ml-assignment/blob/main/work/notebooks/%20%20%20%20w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flyrank-bih/flyrank-ml-internship-starter/blob/main/work/notebooks/w02_ml_task_framing.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
lane = "Ranking"

reason = """
This task is a ranking problem because we need to rank pages
based on which should be updated first.
"""

print(lane)
print(reason)
# Out:
# Ranking
#
# This task is a ranking problem because we need to rank pages
# based on which should be updated first.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
target = """
Predict which pages should be refreshed first based on
traffic, clicks, impressions, and ranking position.
"""

print(target)
# Out:
# Predict which pages should be refreshed first based on
# traffic, clicks, impressions, and ranking position.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
metric = """
The model is successful if it correctly ranks the pages
that need updates before traffic drops.
"""

print(metric)
# Out:
# The model is successful if it correctly ranks the pages
# that need updates before traffic drops.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
unit_analysis = """
One row in the dataframe represents one webpage with its
performance metrics such as clicks, impressions, CTR,
position, and other SEO-related features.
"""

print(unit_analysis)
# Out:
# One row in the dataframe represents one webpage with its
# performance metrics such as clicks, impressions, CTR,
# position, and other SEO-related features.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
why_ml = """
Machine learning performs better than a fixed rule because
page performance depends on many factors that interact
together. A fixed if-statement cannot capture these complex
patterns, while an ML model can learn them from data.
"""

print(why_ml)
# Out:
# Machine learning performs better than a fixed rule because
# page performance depends on many factors that interact
# together. A fixed if-statement cannot capture these complex
# patterns, while an ML model can learn them from data.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
